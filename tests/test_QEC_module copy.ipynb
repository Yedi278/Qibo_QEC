# %% [markdown]
# # Testing qibo_qec Module

# %% [markdown]
# Basic imports and graphic settings:

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')    # Use dark background for plots

import qibo
assert qibo.__version__ >= "0.2.20", "This script requires qibo version 0.2.20 or higher."

from qibo import Circuit, gates
from qibo.gates import *

from qibo.ui import plot_circuit, plot_density_hist, visualize_state

### Import QEC module ###
from qibo_qec import QEC


custom_style = {                    # Define a custom style for the circuit plot
    "facecolor" : "#000000",
    "edgecolor" : "#ffffff",
    "linecolor" : "#ffffff",
    "textcolor" : "#ffffff",
    "fillcolor" : "#c41b1b",
    "gatecolor" : "#9000ff",
    "controlcolor" : "#360000"
}

# %% [markdown]
# Basic Qibo Circuit creation:

# %%
qc = Circuit(1)

qc.add(gates.M(0))

plot_circuit(qc, style=custom_style)
plt.title("Original Circuit before QEC")
plt.show()

# %% [markdown]
# Application of Quantum Error Correction:

# %%
qec = QEC(code_type="bit_flip")
# encoded_circuit = qec.apply_code(qc)

test_gates = [gates.X(0)]  # Example test gate to introduce an error
encoded_circuit = qec.apply_code(qc, test_gates=test_gates, correction=False)

plot_circuit(encoded_circuit, style=custom_style)
plt.title("Circuit after applying Bit-Flip QEC")
plt.show()
# Out:
# Initialized QEC with code type: bit_flip
# Applying bit_flip code to a circuit with 5 qubit(s).

# %%
qibo.set_backend("qibojit")
qibo.set_device("/CPU:0")
qibo.set_threads(20)

res = encoded_circuit(nshots=10)
visualize_state(res)
plt.show()
# Out:
# [Qibo 0.2.21|INFO|2025-11-01 16:36:32]: Using qibojit (numba) backend on /CPU:0
# [Qibo 0.2.21|INFO|2025-11-01 16:36:32]: Using qibojit (numba) backend on /CPU:0
# {'backend': qibojit (numba), 'density_matrix': False, 'nqubits': 5, '_state': array([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#        0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j]), 'measurements': [<qibo.gates.measurements.M object at 0x7f20a4d5dc10>, <qibo.gates.measurements.M object at 0x7f20a4d2b440>, <qibo.gates.measurements.M object at 0x7f20a4d5d100>], 'nshots': 10, '_measurement_gate': None, '_probs': array([0., 0., 0., 0., 1., 0., 0., 0.]), '_samples': None, '_frequencies': None, '_repeated_execution_frequencies': None}
